# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('IPLDATA.csv')
df.head(60)
# Out:
#                Player Name       Team Nationality Player_Type  Capped  \
# 0           Shikhar Dhawan     Punjab      Indian      Batter       1
# 1            Shreyas Iyer     Kolkata      Indian      Batter       1
# 2           Faf Du Plessis  Bangalore    Overseas      Batter       1
# 3           Manish Pandey     Lucknow      Indian      Batter       1
# 4          Shimron Hetmyer  Rajasthan    Overseas      Batter       1
# 5            Robin Uthappa    Chenai       Indian      Batter       1
# 6                Jason Roy    Gujarat    Overseas      Batter       1
# 7         Devdutt Padikkal  Rajasthan      Indian      Batter       1
# 8              Priyam Garg  Hyderabad      Indian      Batter       1
# 9      Abhinav Sadarangani   Gujarat       Indian      Batter       0
# 10           Dewald Brevis     Mumbai    Overseas      Batter       0
# 11           Ashwin Hebbar      Delhi      Indian      Batter       0
# ...

# %%
df.describe()
# Out:
#            Capped  Matches_Played         Runs     Average  Strike_Rate  \
# count  235.000000      215.000000   165.000000  161.000000   163.000000
# mean     0.838298       43.897674   840.575758   21.792391   121.009939
# std      0.561802       48.695302  1270.341831   11.664156    30.739189
# min      0.000000        1.000000     0.000000    0.000000     0.000000
# 25%      0.500000       11.500000    67.000000   13.800000   112.635000
# 50%      1.000000       25.000000   289.000000   22.410000   128.630000
# 75%      1.000000       56.000000   954.000000   29.300000   137.550000
# max      2.000000      220.000000  6283.000000   58.500000   190.240000
#
#           Wickets  Bowling_average     Economy  Bowling_Strike_Rate  \
# count  140.000000       135.000000  143.000000           119.000000
# mean    31.485714        32.907185    8.223182            24.686134
# std     36.872420        18.191441    1.223541            12.982049
# ...

# %%
df.isna().sum()
# Out:
# Player Name              0
# Team                     0
# Nationality              0
# Player_Type              0
# Capped                   0
# Matches_Played          20
# Runs                    70
# Average                 74
# Strike_Rate             72
# Wickets                 95
# Bowling_average        100
# Economy                 92
# Bowling_Strike_Rate    116
# Catches                208
# Run_outs               208
# Stumps                 208
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player Name          235 non-null    object
#  1   Team                 235 non-null    object
#  2   Nationality          235 non-null    object
#  3   Player_Type          235 non-null    object
#  4   Capped               235 non-null    int64
#  5   Matches_Played       215 non-null    float64
#  6   Runs                 165 non-null    float64
#  7   Average              161 non-null    float64
#  8   Strike_Rate          163 non-null    float64
#  9   Wickets              140 non-null    float64
#  10  Bowling_average      135 non-null    float64
#  11  Economy              143 non-null    float64
#  12  Bowling_Strike_Rate  119 non-null    float64
#  13  Catches              27 non-null     float64
#  14  Run_outs             27 non-null     float64
# ...

# %% [markdown]
# # Cleaning The Data

# %%
#For Batters
batters = df.loc[(df['Player_Type'] == 'Batter')]
capped_Batters = batters.loc[(batters['Capped'] == 1)]

capped_Batters = capped_Batters[['Player Name' , 
                                'Team' , 
                                'Nationality' , 
                                'Matches_Played' , 
                                'Runs' , 
                                'Average' , 
                                'Strike_Rate']]

# %%
capped_Batters.head(3)
# Out:
#       Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 0  Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 1   Shreyas Iyer     Kolkata      Indian            87.0  2375.0    31.67
# 2  Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
#
#    Strike_Rate
# 0       126.60
# 1       123.96
# 2       131.09

# %%
#For Bowlers
bowlers = df.loc[(df['Player_Type'] == 'Bowler ')]
new_Bowlers = bowlers.loc[(bowlers['Capped'] == 1)]
capped_Bowlers = new_Bowlers[['Player Name' , 
                            'Team' , 
                            'Nationality' , 
                            'Matches_Played' , 
                            'Wickets' , 
                            'Bowling_average' , 
                            'Economy' , 
                            'Bowling_Strike_Rate']]

# %%
capped_Bowlers.head(3)
# Out:
#         Player Name       Team Nationality  Matches_Played  Wickets  \
# 36   Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 37     Trent Boult   Rajasthan    Overseas            62.0     76.0
# 38  Mohammad Shami     Gujarat      Indian            77.0     79.0
#
#     Bowling_average  Economy  Bowling_Strike_Rate
# 36            20.53     8.21                15.00
# 37            26.09     8.40                18.64
# 38            30.41     8.63                21.14

# %%
keepers = df.loc[(df['Player_Type'] == 'Keeper')]
capped_Keeper = keepers.loc[(keepers['Capped'] == 1)]
capped_Keeper = capped_Keeper[['Player Name' , 
                            'Team' , 
                            'Nationality' , 
                            'Matches_Played' , 
                            'Runs' , 
                            'Average' , 
                            'Strike_Rate' , 
                            'Catches' , 
                            'Run_outs' , 
                            'Stumps']]

# %%
capped_Keeper.head(3)
# Out:
#          Player Name     Team Nationality  Matches_Played    Runs  Average  \
# 105  Quinton De Kock  Lucknow    Overseas            77.0  2256.0     31.3
# 106    Ambati Rayudu  Chennai      Indian           175.0  3916.0     29.4
# 107     Ishan Kishan   Mumbai      Indian            61.0  1452.0     28.5
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 105        130.9     53.0       0.0    14.0
# 106        127.5     58.0      12.0     2.0
# 107        136.3     19.0       1.0     2.0

# %%
Allrounders = df.loc[(df['Player_Type'] == 'Allrounder')]
capped_Allrounder = Allrounders.loc[(Allrounders['Capped'] == 1)]
capped_Allrounder = capped_Allrounder[['Player Name' , 
                            'Team' , 
                            'Nationality' , 
                            'Matches_Played' , 
                            'Runs' , 
                            'Average' , 
                            'Strike_Rate' , 
                            'Wickets' , 
                            'Bowling_average' , 
                            'Economy' ,                                        
                            'Bowling_Strike_Rate']]

# %%
capped_Allrounder.head(3)
# Out:
#               Player Name       Team Nationality  Matches_Played    Runs  \
# 127  Ravichandran Ashwin   Rajasthan      Indian           167.0   456.0
# 128          Pat Cummins     Kolkata    Overseas            37.0   316.0
# 129         Dwayne Bravo     Chennai    Overseas           151.0  1537.0
#
#      Average  Strike_Rate  Wickets  Bowling_average  Economy  \
# 127    11.12       109.88    145.0            27.80     6.91
# 128    19.75       140.44     38.0            30.13     8.24
# 129    22.94       130.25    167.0            24.32     8.36
#
#      Bowling_Strike_Rate
# 127                24.12
# 128                21.95
# 129                17.44

# %%
capped_Batters =capped_Batters.fillna(0)
capped_Bowlers =capped_Bowlers.fillna(0)
capped_Keeper =capped_Keeper.fillna(0)
capped_Allrounder =capped_Allrounder.fillna(0)

# %%
print(capped_Batters.isna().sum())
print(capped_Bowlers.isna().sum())
print(capped_Keeper.isna().sum())
print(capped_Allrounder.isna().sum())
# Out:
# Player Name       0
# Team              0
# Nationality       0
# Matches_Played    0
# Runs              0
# Average           0
# Strike_Rate       0
# dtype: int64
# Player Name            0
# Team                   0
# Nationality            0
# Matches_Played         0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# dtype: int64
# Player Name       0
# Team              0
# Nationality       0
# Matches_Played    0
# Runs              0
# Average           0
# Strike_Rate       0
# Catches           0
# Run_outs          0
# Stumps            0
# dtype: int64
# Player Name            0
# Team                   0
# Nationality            0
# Matches_Played         0
# Runs                   0
# Average                0
# Strike_Rate            0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# dtype: int64

# %% [markdown]
# # Intial Analysis

# %%
star_Batters = capped_Batters.loc[(capped_Batters['Average'] >=32.0)]

star_Batters_Average = star_Batters.sort_values('Average' , ascending=False)
star_Batters_Strike_Rate = star_Batters.sort_values('Strike_Rate' , ascending =False)
star_Batters_runs = star_Batters.sort_values('Runs' , ascending = False)
star_Batters_matches = star_Batters.sort_values('Matches_Played' , ascending = False)

# %%
star_Batters_Average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
#
#      Strike_Rate
# 212       136.38
# 231       132.13
# 19        139.97
# 207       131.27
# 208       129.95
# 2         131.09
# 0         126.60
# 26        136.51

# %%
star_Batters_Strike_Rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
#
#      Strike_Rate
# 19        139.97
# 26        136.51
# 212       136.38
# 231       132.13
# 207       131.27
# 2         131.09
# 208       129.95
# 0         126.60

# %%
star_Batters_runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 212       136.38
# 2         131.09
# 26        136.51
# 207       131.27
# 231       132.13

# %%
star_Batters_matches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 2         131.09
# 212       136.38
# 26        136.51
# 207       131.27
# 231       132.13

# %% [markdown]
# ### from our analysis we rank top three batsman.
# ### 1.KL
# ### 2.David
# ### 3.Virat

# %%
star_Bowlers = capped_Bowlers[(capped_Bowlers['Bowling_average'] <=24.0)]

star_Bowlers_average = star_Bowlers.sort_values('Bowling_average')
star_Bowlers_Strike_Rate = star_Bowlers.sort_values('Bowling_Strike_Rate')
star_Bowlers_Wickets = star_Bowlers.sort_values('Wickets' , ascending=False)
star_Bowlers_economy = star_Bowlers.sort_values('Economy')
star_Bowlers_matches = star_Bowlers.sort_values('Matches_Played' , ascending = False)

# %%
star_Bowlers_average
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
#
# ...

# %%
star_Bowlers_Strike_Rate
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
#
# ...

# %%
star_Bowlers_Wickets
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
#
# ...

# %%
star_Bowlers_economy
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
#
# ...

# %%
star_Bowlers_matches
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
#
# ...

# %% [markdown]
# ### From our analysis we rank top Four Bowlers.
# ### 1. Kagiso Rabada
# ### 2. Jasprit Bumrah
# ### 3. Yuzvendra Chahal
# ### 4. Nathan Coulter-Nile

# %%
star_allrounders = capped_Allrounder.loc[(capped_Allrounder['Strike_Rate'] >=140.0)]

star_allrounders_Average = star_allrounders.sort_values('Average' , ascending = False)
star_allrounders_Strike_Rate = star_allrounders.sort_values('Strike_Rate' , ascending = False)
star_allrounders_Runs = star_allrounders.sort_values('Runs' , ascending = False)
star_allrounders_Matches = star_allrounders.sort_values('Matches_Played' , ascending = False)
star_allrounders_Bowling_average = star_allrounders.sort_values('Bowling_average')
star_allrounders_Bowling_Strike_Rate = star_allrounders.sort_values('Bowling_Strike_Rate')
star_allrounders_Wickets = star_allrounders.sort_values('Wickets' , ascending = False)
star_allrounders_Economy = star_allrounders.sort_values('Economy')

# %%
star_allrounders_Average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
star_allrounders_Strike_Rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
#
# ...

# %%
star_allrounders_Runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
star_allrounders_Matches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
star_allrounders_Bowling_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
#
# ...

# %%
star_allrounders_Bowling_Strike_Rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
#
# ...

# %%
star_allrounders_Wickets
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
star_allrounders_Economy
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
#
# ...

# %% [markdown]
# ### Top Allrounders
# ### 1.Andre Russell
# ### 2.Sunil Narine
# ### 3.Hardik Pandya
# ### 4.Jofra Archer

# %%
star_Keeper = capped_Keeper.loc[(capped_Keeper['Average'] >=25.0)]

star_Keeper_Average = star_Keeper.sort_values('Average' , ascending = False)
star_Keeper_Strike_Rate = star_Keeper.sort_values('Strike_Rate' , ascending = False)
star_Keeper_Runs = star_Keeper.sort_values('Runs' , ascending = False)
star_Keeper_Matches = star_Keeper.sort_values('Matches_Played' , ascending = False)
star_Keeper_Catches = star_Keeper.sort_values('Catches' , ascending = False)
star_Keeper_Runouts = star_Keeper.sort_values('Run_outs' , ascending = False)
star_Keeper_Stumps = star_Keeper.sort_values('Stumps' , ascending = False)

# %%
star_Keeper_Average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 108       142.20     18.0       1.0     4.0
# ...

# %%
star_Keeper_Strike_Rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 219       150.00     34.0       3.0     1.0
# ...

# %%
star_Keeper_Runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
star_Keeper_Matches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
star_Keeper_Catches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
star_Keeper_Runouts
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
star_Keeper_Stumps
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %% [markdown]
# ### Top Keepers
# ### 1. MS Dhoni
# ### 2. Dinesh Karthik
# ### 3. Rishabh Pant

# %% [markdown]
# #  Visualization For Enhanced Analysis.

# %%
# For Batsman data
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Strike_Rate' , data=star_Batters)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Strike_Rate'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Runs' , data=star_Batters)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Runs'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Average' , data=star_Batters)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Average'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Matches_Played' , data=star_Batters)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Matches_Played'>

# %%
# For Bowlers data
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Bowling_average' , data=star_Bowlers)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Bowling_average'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Economy' , data=star_Bowlers)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Economy'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Bowling_Strike_Rate' , data=star_Bowlers)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Bowling_Strike_Rate'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Wickets' , data=star_Bowlers)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Wickets'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Matches_Played' , data=star_Bowlers)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Matches_Played'>

# %%
# For Allrounders
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Strike_Rate' , data=star_allrounders)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Strike_Rate'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Average' , data=star_allrounders)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Average'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Matches_Played' , data=star_allrounders)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Matches_Played'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Runs' , data=star_allrounders)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Runs'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Bowling_average' , data=star_allrounders)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Bowling_average'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Economy' , data=star_allrounders)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Economy'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Bowling_Strike_Rate' , data=star_allrounders)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Bowling_Strike_Rate'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Wickets' , data=star_allrounders)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Wickets'>

# %%
#For Keepers
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Average' , data=star_Keeper)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Average'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Runs' , data=star_Keeper)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Runs'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Strike_Rate' , data=star_Keeper)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Strike_Rate'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Catches' , data=star_Keeper)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Catches'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Run_outs' , data=star_Keeper)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Run_outs'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Stumps' , data=star_Keeper)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Stumps'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name' , y='Matches_Played' , data=star_Keeper)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Matches_Played'>

# %%
star_Batters.reset_index(drop=True)
Match_values= [star_Batters.iloc[6]['Matches_Played'] , star_Batters.iloc[2]['Matches_Played'] , star_Batters.iloc[5]['Matches_Played']]
runs_values= [star_Batters.iloc[6]['Runs'] , star_Batters.iloc[2]['Runs'] , star_Batters.iloc[5]['Runs']]
average_values= [star_Batters.iloc[6]['Average'] , star_Batters.iloc[2]['Average'] , star_Batters.iloc[5]['Average']]
Strike_Rate_Values= [star_Batters.iloc[6]['Strike_Rate'] , star_Batters.iloc[2]['Strike_Rate'] , star_Batters.iloc[5]['Strike_Rate']]
Labels = ['KL Rahul' , 'David Warner' , 'Virat Kohli']

fig, axes = plt.subplots(2,2, figsize=(8,8))
axes[0][0].set_title('Matches_Played')
axes[0][1].set_title('Runs in an ipl career')
axes[1][0].set_title('Strike Rate')
axes[1][1].set_title('Average')
sns.barplot(x=Labels , y=Match_values , ax=axes[0][0])
sns.barplot(x=Labels , y=runs_values , ax=axes[0][1])
sns.barplot(x=Labels , y=Strike_Rate_Values , ax=axes[1][0])
sns.barplot(x=Labels , y=average_values , ax=axes[1][1])
# Out:
# <AxesSubplot:title={'center':'Average'}>

# %%
star_allrounders.reset_index(drop=True)
matches_values = [star_allrounders.iloc[5]['Matches_Played'] , star_allrounders.iloc[-2]['Matches_Played'] , star_allrounders.iloc[6]['Matches_Played']]
runs_values = [star_allrounders.iloc[5]['Runs'] , star_allrounders.iloc[-2]['Runs'] , star_allrounders.iloc[6]['Runs']]
average_values = [star_allrounders.iloc[5]['Average'] , star_allrounders.iloc[-2]['Average'] , star_allrounders.iloc[6]['Average']]
strike_rate_values = [star_allrounders.iloc[5]['Strike_Rate'] , star_allrounders.iloc[-2]['Strike_Rate'] , star_allrounders.iloc[6]['Strike_Rate']]
bowling_strike_rate_values = [star_allrounders.iloc[5]['Bowling_Strike_Rate'] , star_allrounders.iloc[-2]['Bowling_Strike_Rate'] , star_allrounders.iloc[6]['Bowling_Strike_Rate']]
bowling_average_values = [star_allrounders.iloc[5]['Bowling_average'] , star_allrounders.iloc[-2]['Bowling_average'] , star_allrounders.iloc[6]['Bowling_average']]
wickets_values = [star_allrounders.iloc[5]['Wickets'] , star_allrounders.iloc[-2]['Wickets'] , star_allrounders.iloc[6]['Wickets']]
economy_values = [star_allrounders.iloc[5]['Economy'] , star_allrounders.iloc[-2]['Economy'] , star_allrounders.iloc[6]['Economy']]

Lables=['Andre Russell' , 'Sunil Narine' , 'Hardik Pandya']

fig, axes = plt.subplots(4,2, figsize=(20,20))
axes[0][0].set_title('Matches')
axes[0][1].set_title('Runs')
axes[1][0].set_title('Average')
axes[1][1].set_title('Strike Rate')
axes[2][0].set_title('Bowling strike rate')
axes[2][1].set_title('Bowling average')
axes[3][0].set_title('Wickets')
axes[3][1].set_title('Economy')
sns.barplot(x=Lables , y=matches_values , ax=axes[0][0])
sns.barplot(x=Lables , y=runs_values , ax=axes[0][1])
sns.barplot(x=Lables , y=average_values , ax=axes[1][0])
sns.barplot(x=Lables , y=strike_rate_values , ax=axes[1][1])
sns.barplot(x=Lables , y=bowling_strike_rate_values , ax=axes[2][0])
sns.barplot(x=Lables , y=bowling_average_values , ax=axes[2][1])
sns.barplot(x=Lables , y=wickets_values , ax=axes[3][0])
sns.barplot(x=Lables , y=economy_values , ax=axes[3][1])
# Out:
# <AxesSubplot:title={'center':'Economy'}>

# %%
star_Bowlers.reset_index(drop=True)
Matches_values = [star_Bowlers.iloc[-2]['Matches_Played'] , star_Bowlers.iloc[0]['Matches_Played'] , star_Bowlers.iloc[7]['Matches_Played'] , star_Bowlers.iloc[1]['Matches_Played']]
Wickets_values = [star_Bowlers.iloc[-2]['Wickets'] , star_Bowlers.iloc[0]['Wickets'] , star_Bowlers.iloc[7]['Wickets'] , star_Bowlers.iloc[1]['Wickets']]
Bowling_Average_values = [star_Bowlers.iloc[-2]['Bowling_average'] , star_Bowlers.iloc[0]['Bowling_average'] , star_Bowlers.iloc[7]['Bowling_average'] , star_Bowlers.iloc[1]['Bowling_average']]
Bowling_Strike_Rate_values = [star_Bowlers.iloc[-2]['Bowling_Strike_Rate'] , star_Bowlers.iloc[0]['Bowling_Strike_Rate'] , star_Bowlers.iloc[7]['Bowling_Strike_Rate'] , star_Bowlers.iloc[1]['Bowling_Strike_Rate']]
Economy_values = [star_Bowlers.iloc[-2]['Economy'] , star_Bowlers.iloc[0]['Economy'] , star_Bowlers.iloc[7]['Economy'] , star_Bowlers.iloc[1]['Economy']]

Lables=['Jasprit Bumrah' , 'Kagiso Rabada' , 'Nathan Coulter-Nile' , 'Yuzvendra Chahal']

fig, axes= plt.subplots(3,2, figsize=(20,20))
axes[0][0].set_title('Matches Played')
axes[0][1].set_title('wickets')
axes[1][0].set_title('Bowling Average')
axes[1][1].set_title('Bowling Strike Rate')
axes[2][0].set_title('Economy')
sns.barplot(x=Lables , y=Matches_values , ax=axes[0][0])
sns.barplot(x=Lables , y=Wickets_values, ax=axes[0][1])
sns.barplot(x=Lables , y=Bowling_Average_values , ax=axes[1][0])
sns.barplot(x=Lables , y=Bowling_Strike_Rate_values , ax=axes[1][1])
sns.barplot(x=Lables , y=Economy_values , ax=axes[2][0])
# Out:
# <AxesSubplot:title={'center':'Economy'}>

# %%
star_Keeper.reset_index(drop=True)

matches_Values = [star_Keeper.iloc[8]['Matches_Played'] , star_Keeper.iloc[8]['Runs']]
average_values = [star_Keeper.iloc[8]['Average'] , star_Keeper.iloc[8]['Strike_Rate']]
keeping_values = [star_Keeper.iloc[8]['Catches'] , star_Keeper.iloc[8]['Stumps'] , star_Keeper.iloc[8]['Run_outs']]

label1=['Matches' , 'Runs']
label2=['Average' , 'strike_rate']
label3=['catches' , 'stumps' , 'run_outs']

fig,  axes = plt.subplots(1,3, figsize=(20,10))
axes[0].set_title('Matches and runs')
axes[1].set_title('Average and strike rate')
axes[2].set_title('keeping status')

sns.barplot(x=label1 , y=matches_Values , ax=axes[0])
sns.barplot(x=label2 , y=average_values , ax=axes[1])
sns.barplot(x=label3 , y=keeping_values , ax=axes[2])
# Out:
# <AxesSubplot:title={'center':'keeping status'}>

# %%
Batter1 = star_Batters.loc[(star_Batters["Player Name"] == 'KL Rahul ')]
Batter2 = star_Batters.loc[(star_Batters["Player Name"] == 'David Warner ')]
Batter3 = star_Batters.loc[(star_Batters["Player Name"] == 'Virat Kohli')]

bowler1 = star_Bowlers.loc[(star_Bowlers["Player Name"] == 'Yuzvendra Chahal ')]
bowler2 = star_Bowlers.loc[(star_Bowlers["Player Name"] == 'Jasprit Bumrah')]
bowler3 = star_Bowlers.loc[(star_Bowlers["Player Name"] == 'Nathan Coulter-Nile')]
bowler4 = star_Bowlers.loc[(star_Bowlers["Player Name"] == 'Kagiso Rabada ')]

allrounder1 = star_allrounders.loc[(star_allrounders["Player Name"] == 'Andre Russell')]
allrounder2 = star_allrounders.loc[(star_allrounders["Player Name"] == 'Sunil Narine ')]
allrounder3 = star_allrounders.loc[(star_allrounders["Player Name"] == 'Hardik Pandya')]

keeper = star_Keeper.loc[(star_Keeper['Player Name'] == 'MS Dhoni')]

# %%
final = [Batter1 , Batter2 , Batter3 , allrounder1 , allrounder2 , allrounder3 , keeper , bowler1 , bowler2 , bowler3 , bowler4]
final_team = pd.concat(final)
final_team = final_team.drop(labels=['Matches_Played' , 'Runs' , 'Average' , 'Strike_Rate' , 'Wickets' , 'Bowling_average' , 'Economy' , 'Bowling_Strike_Rate' , 'Catches' , 'Run_outs' , 'Stumps'] , axis=1)
final_team.reset_index(drop = True)
# Out:
#             Player Name       Team Nationality
# 0             KL Rahul     Lucknow      Indian
# 1         David Warner       Delhi    Overseas
# 2           Virat Kohli  Bangalore      Indian
# 3         Andre Russell    Kolkata    Overseas
# 4         Sunil Narine     Kolkata    Overseas
# 5         Hardik Pandya    Gujarat      Indian
# 6              MS Dhoni    Chennai      Indian
# 7     Yuzvendra Chahal   Rajasthan      Indian
# 8        Jasprit Bumrah     Mumbai      Indian
# 9   Nathan Coulter-Nile  Rajasthan    Overseas
# 10       Kagiso Rabada      Punjab    Overseas

# %% [markdown]
# # So the Best 11 are:
# #### KL Rahul
# #### David Warner
# #### Virat Kohli
# #### Andre Russell
# #### Sunil Narine
# #### Hardik Pandya
# #### MS Dhoni
# #### Yuzvendra Chahal
# #### Jasprit Bumrah
# #### Nathan Coulter-Nile
# #### Kagiso Rabada
